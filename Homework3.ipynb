# %%
a = int(input())
b = int(input())
print("Gia tri ban dau a:",a)
print("Gia tri ban dau b:",b)
a = a^b
b = a^b
a = a^b
print("Gia tri sau cua a:",a)
print("Gia tri sau cua b:",b)
# Out:
#  10
#  17
# Gia tri ban dau a: 10
# Gia tri ban dau b: 17
# Gia tri sau cua a: 17
# Gia tri sau cua b: 10

# %%
n = int(input())
if n > 0 and n & (n-1) == 0:
    print(n,"la luy thua cua 2")
else:
    print(n,"khong la luy thua cua 2")
# Out:
#  6
# 6 khong la luy thua cua 2

# %%
import math
m,n = map(float,input().split())
a = m / n
print(math.floor(a))
# Out:
#  6 4
# 1

# %%
import math
m,n = map(float,input().split())
a = m/n
print(math.ceil(a))
# Out:
#  8 3
# 3

# %%
x = int(input())
if x%2 == 0:
    print("Even")
else:
    print("Odd")
# Out:
#  4
# Even

# %%
a, b = map(int,input().split())
if a < 0 and b<0:
    print("True")
else:
    print("False")
# Out:
#  -1 -2
# True

# %%
a = input()
b = input()
if len(a)>len(b):
    print("True")
else:
    print("False")

# %%
a, b,c = map(int,input().split())
if a>0 and b>0 and c>0:
    if a+b>c and a+c>b and b+c>a:
        print("Tam giac")
    else:
        print("Khong phai tam giac")
else:
    print("Khong hop le")

# %%
a,b,c,d = map(int,input().split())
print(max(a,b,c,d))
# Out:
#  1 2 3 4
# 4

# %%
a, b,c = map(int,input().split())
if a>0 and b>0 and c>0:
    if a+b>c and a+c>b and b+c>a:
        if a==b==c:
            print("Tam giac deu")
        elif a==b or b==c or c==a:
            print("Tam giac can")
        else:
            print("Tam giac thuong")
    else:
        print("Khong phai tam giac")
# Out:
#  2 2 2
# Tam giac deu

# %%
n = int(input())
if n%4 or n%400:
    print("Yes")
else:
    print("No")
# Out:
#  2024
# Yes

# %%
a = int(input())
b = int(input())
x = -b/a
if a == 0:
    if b == 0:
        print("Vo so nghiem")
    else:
        print("Vo nghiem")
else:
    print("Nghiem x=",round(x,2))
# Out:
#  3
#  -8
# Nghiem x= 2.67

# %%
n = int(input())
if 0<= n <=10:
    if n>= 8:
        print("gioi")
    elif 6.5 <= n < 8:
        print("kha")
    elif 5.0 <= n < 6.5:
        print("trung binh")
    elif n< 5:
        print("yeu")
else:
    print("Invalid")

# %%
x = float(input())
nguyen = int(x)
thapphan = abs(x-nguyen)
if x>= 0 or x == nguyen:
    floor = nguyen
else:
    floor = nguyen - 1
if x<= 0 or x== nguyen:
    ceil = nguyen
else:
    ceil = nguyen + 1
if x >= 0:
    if thapphan >= 0.5:
        rounded = nguyen + 1
    else:
        rounded = nguyen
else:
    if thapphan >= 0.5:
        rounded = nguyen - 1
    else:
        rounded = nguyen
print(ceil,floor,rounded)
# Out:
#  2.5
# 3 2 3

# %%
a,b,c,d = map(int,input().split())
x = b/a
if b*x == c and c*x==d:
    print("La cap so nhan")
else:
    print("khong phai cap so nhan")
# Out:
#  2 4 8 16
# La cap so nhan
