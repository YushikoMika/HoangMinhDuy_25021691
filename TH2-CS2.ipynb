# %%
#W2A1
print("Hello World", sep = ' ')
# Out:
# Hello World

# %%
#W2A2
name = input()
print("Hello ",name)
# Out:
#  monke
# Hello  monke

# %%
#W2A3
a= float(input())
b= float(input())
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a//b)
print(a%b)
# Out:
#  10
#  2
# 12.0
# 8.0
# 20.0
# 5.0
# 5.0
# 0.0

# %%
#W2A4
a1, b1, c1, a2, b2, a3 = map(int,input().split())
print(((a1+b1+c1)+2*(a2+b2)+3*a3)/10)
# Out:
#  1 2 3 4 5 6
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 #W2A4
#       2 a1, b1, c1, a2, b2, a3 = input().split()
# ----> 3 print(((a1+b1+c1)+2*(a2+b2)+3*a3)/10)
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %%
#W2A5
a,b = map(int, input().split())
print(a**b)

# %%
#W2A6
str= input("Nhập chữ cái viết thường:",)
print(str.upper())
# Out:
# Nhập chữ cái viết thường: a
# A

# %%
#W2A7
print("A= ",((13**2)*3)+5)
print("B= ",13**2*3+5)
# Out:
# A=  512
# B=  512

# %%
#W2A8
C = float(input())
print("F= ",(9/5)*C+32)
# Out:
#  18
# F=  64.4

# %%
#W2A9
x = float(input())
print(1.4*x+10)
# Out:
#  20
# 38.0

# %%
#W2A10
name1 = input()
name2 = input()
name3 = input()
print("Hi",name3,",",name2,"and ",name1)
# Out:
#
#  b
#  c
# Hi c , b and

# %%
#W2A11
h = int(input())
m = int(input())
print(h*3600, m*60)
# Out:
#  1
#  20
# 3600 1200

# %%
#W2A12
n= int(input())
print(n*n*6)
# Out:
#  2
# 24

# %%
#W2A13
a, b = map(int, input().split())
print(a*b)
# Out:
#  1 4
# 4

# %%
#W2A14
a, b = map(int, input().split())
a= a+b
b=a-b
a=a-b
print(a,b)
# Out:
#  5 12
# 12 5

# %%
#W2A15
n = int(input())
print(6*n*(n-1)+1)
# Out:
#  5
# 121

# %%
#W2A16
print("Spring")
print("Summer")
print("Autumn")
print("Winter")
# Out:
# Spring
# Summer
# Autumn
# Winter

# %%
#W2A17
print("*")
print("***")
print("*****")
# Out:
# *
# ***
# *****

# %%
#W2A18
print("### # #  ### ###")
print(" #  #  #  #   #")
print(" #  #   # #   #")
print(" #  #  #  #   #")
print(" #  # #   #   #")
# Out:
# ### # #  ### ###
#  #  #  #  #   #
#  #  #   # #   #
#  #  #  #  #   #
#  #  # #   #   #

# %%
#W2A19
print("Monday")
print("Tuesday")
print("Wednesday")
print("Thursday")
print("Friday")
print("Saturday")
print("Sunday")
# Out:
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday

# %%
#W2A20
print("January")
print("February")
print("March")
print("April")
print("May")
print("June")
print("July")
print("August")
print("September")
print("October")
print("November")
print("December")
# Out:
# January
# February
# March
# April
# May
# June
# July
# August
# September
# October
# November
# December

# %%
#W2A21
n = 1
while n <= 10:
    print("Hello, world")
    n = n+1
# Out:
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
