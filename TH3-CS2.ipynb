# %%
n = int(input())
print(2*n)
# Out:
#  3
# 6

# %%
a, b = map(int, input().split())
c = a*b - ((a/2)**2)*3.14
print(round(c,2))
# Out:
#  1 2
# 1.21

# %%
c = input()
if len(c) != 1:
    print("Nhap mot ki tu duy nhat")
else:
    if c.islower():
        print(c.upper())
    elif c.isupper():
        print(c.lower())
    else:
        print("Khong phai la chu cai")
# Out:
#  a
# A

# %%
c = input()
if c.isalpha():
    print(c,"la ki tu alphabet")
else:
    print(c,"khong la ki tu alphabet")
# Out:
#  2
# 2 khong la ki tu alphabet

# %%
c = input()
if len(c) != 1 and c.islower():
    print("Invalid")
else:
    if c == "A":
        print("z")
    else:
        b = c.lower()
        a = chr(ord(b) - 1)
        print(a)
# Out:
#  B
# a

# %%
a, b, c = map(int, input().split())
if a+b>c and a+c>b and b+c>a:
    print("Tam giac")
    print(a+b+c)
    p= (a+b+c)/2
    print((p*(p-a)*(p-b)*(p-c))**(1/2))
else:
    print("Khong phai tam giac")
# Out:
#  1 2 5
# Khong phai tam giac

# %%
string = input()
if len(string) >= 20:
    print(string[4])
    print(string[8])
else:
    print("Khong hop le")
# Out:
#  abcdefghijklmnopqrstuvwxyz
# e
# i

# %%
ho_ten = input()
thang_truoc = int(input())
thang_sau = int(input())
so_kwh = thang_sau - thang_truoc
tien = 0
if so_kwh <= 0:
    print("Khong hop le")
else:
    if so_kwh <= 50:
        tien = so_kwh*1984
    elif so_kwh <= 100:
        tien = 99200 + (so_kwh -50)*2050
    elif so_kwh <= 200:
        tien = 201700 + (so_kwh-100)*2380
    elif so_kwh <= 300:
        tien = 439700 + (so_kwh - 200)*2998
    elif so_kwh <= 400:
        tien = 739500 + (so_kwh - 300)*3350
    elif so_kwh >400:
        tien = 1074500+ (so_kwh -400)* 3460
print("Ho va ten:",ho_ten)
print("Tien phai tra la:",tien*1.8)
# Out:
#  duy
#  1000
#  900
# Khong hop le
# Ho va ten: duy
# Tien phai tra la: 0.0

# %%
n = int(input())
if n%2 == 0:
    print("So chan")
else:
    print("So le")
# Out:
#  2
# So chan

# %%
n = int(input())
if n%5 == 0:
    if n%2 ==0:
        print("False")
    else:
        print("True")
# Out:
#  10
# False

# %%
n = int(input())
if n%3 == 0 and n%5==0:
    print("True")
else:
    print("False")
# Out:
#  5
# False

# %%
n = int(input())
if n >= 18:
    print("Hop le")
else:
    print("Khong hop le")
# Out:
#  13
# Khong hop le

# %%
a = int(input())
b = int(input())
c = a-b
if c > 0:
    print(a)
elif c < 0:
    print(b)
else:
    print("a bang b")
# Out:
#  5
#  6
# a nho hon b

# %%
n = input()
if len(n) != 1:
    print("Invalid")
else:
    if n.isalpha():
        print("n la mot chu cai")
    elif n.isdigit():
        print("n la mot con so")
    else:
        print("n khong phai la chu cai hay so")
# Out:
#  2
# n la mot con so

# %%
n = int(input())
if 0 <= n <= 10:
    if n >= 8:
        print("Gioi")
    elif 6.5 <= n < 8:
        print("Kha")
    elif 5 <= n < 6.5:
        print("Trung binh")
    elif n<5:
        print("Yeu")
else:
    print("Khong hop le")
# Out:
#  7
# Kha

# %%
year = int(input())
if year % 400 == 0 or year % 4 == 0:
    print("Nam nhuan")
else:
    print("Nam khong nhuan")
# Out:
#  2025
# Nam khong nhuan

# %%
so = int(input())
chu = ["Khong","Mot","Hai","Ba","Bon","Nam","Sau","Bay","Tam","Chin"]
if 0 <= so <= 9:
    print(chu[so])
else:
    print("Khong hop le")
# Out:
#  10
# Khong hop le

# %%
diem = int(input())
if diem >= 4:
    print("Qua mon")
else:
    print("Hoc lai")
# Out:
#  3
# Hoc lai

# %%
year = int(input())
tuoi = 2025 - year
if tuoi >= 18:
    print("Hop le")
else:
    print("khong hop le")
# Out:
#  2004
# Hop le
